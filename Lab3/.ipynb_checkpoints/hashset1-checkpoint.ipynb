# %%
import matplotlib.pyplot as plt 
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data_output/random_data_output_python.csv', header = None, names = ['Num', 'Time'])
df
# Out:
#        Num   Time
# 0   100000   1.51
# 1   100000   1.50
# 2   100000   1.49
# 3   100000   1.54
# 4   100000   1.47
# 5   200000   3.01
# 6   200000   2.95
# 7   200000   2.95
# 8   200000   2.94
# 9   200000   2.98
# 10  100000   1.50
# 11  100000   1.53
# 12  100000   1.52
# 13  100000   1.50
# 14  100000   1.57
# 15  200000   2.98
# 16  200000   3.02
# 17  200000   3.02
# 18  200000   3.01
# 19  200000   3.00
# 20  300000   4.83
# 21  300000   4.40
# 22  300000   4.45
# 23  300000   4.43
# 24  300000   4.55
# 25  400000   6.06
# 26  400000   6.15
# 27  400000   5.82
# 28  400000   6.00
# 29  400000   6.01
# 30  500000   7.32
# 31  500000   7.37
# 32  500000   7.31
# 33  500000   7.37
# 34  500000   7.30
# 35  600000   8.84
# 36  600000   8.95
# 37  600000   8.80
# 38  600000   8.79
# 39  600000   9.19
# 40  700000  10.47
# 41  700000  10.75
# 42  700000  10.23
# 43  700000  10.17
# 44  700000  10.34

# %%
x = df.Num
y = df.Time
plt.plot(x,y)
